# %% [markdown]
# ### Exercise 2.4, problem 10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Data/Boston.csv');

# %% [markdown]
# (a) How many rows are in this data set? How many columns? What
# do the rows and columns represent?

# %%
print("Row Count : " + str(len(df)))
print("Column Count : " + str(len(df.columns)))
print("The rows represent a different line of unique values to the predictors")
print("The columns represent different categories of predictors")
# Out:
# Row Count : 506
# Column Count : 14
# The rows represent a different line of unique values to the predictors
# The columns represent different categories of predictors

# %% [markdown]
# (b) Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your findings.

# %%
pd.plotting.scatter_matrix(df)
plt.show()

# %% [markdown]
# *The values tend to look like some values are correlated. However, there is so much information, it is still unclear what is being represented.*

# %% [markdown]
# (c) Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.

# %%
df.corr()["crim"]
# Out:
# Unnamed: 0    0.407407
# crim          1.000000
# zn           -0.200469
# indus         0.406583
# chas         -0.055892
# nox           0.420972
# rm           -0.219247
# age           0.352734
# dis          -0.379670
# rad           0.625505
# tax           0.582764
# ptratio       0.289946
# lstat         0.455621
# medv         -0.388305
# Name: crim, dtype: float64

# %% [markdown]
# *From the calculated p-values, we can see that values like tax and rad tend to hold a higher correlation. Overall, there is lower correlations tho*

# %% [markdown]
# (d) Do any of the census tracts of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
#Graph crime rates with boxplot to find outliers, then determine names of outliers
df.boxplot(column=["crim"])
# Out:
# <AxesSubplot:>

# %%
#Which tracts are outliers by which are above the 75% line
df.loc[df.crim > 3.677083]
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 143         144  4.09740  0.0  19.58     0  0.871  5.468  100.0  1.4118    5
# 356         357  8.98296  0.0  18.10     1  0.770  6.212   97.4  2.1222   24
# 357         358  3.84970  0.0  18.10     1  0.770  6.395   91.0  2.5052   24
# 358         359  5.20177  0.0  18.10     1  0.770  6.127   83.4  2.7227   24
# 359         360  4.26131  0.0  18.10     0  0.770  6.112   81.3  2.5091   24
# ..          ...      ...  ...    ...   ...    ...    ...    ...     ...  ...
# 480         481  5.82401  0.0  18.10     0  0.532  6.242   64.7  3.4242   24
# 481         482  5.70818  0.0  18.10     0  0.532  6.750   74.9  3.3317   24
# 482         483  5.73116  0.0  18.10     0  0.532  7.061   77.0  3.4106   24
# 486         487  5.69175  0.0  18.10     0  0.583  6.114   79.8  3.5459   24
# 487         488  4.83567  0.0  18.10     0  0.583  5.905   53.2  3.1523   24
#
#      tax  ptratio  lstat  medv
# ...

# %%
#Find the average tax rates, then graph the tax rates to fnd the outliers
df.boxplot(column=["tax"])
# Out:
# <AxesSubplot:>

# %%
#Which tracts are outliers by which are above the 75% line
df.loc[df.tax > 666]
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 488         489  0.15086  0.0  27.74     0  0.609  5.454  92.7  1.8209    4
# 489         490  0.18337  0.0  27.74     0  0.609  5.414  98.3  1.7554    4
# 490         491  0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4
# 491         492  0.10574  0.0  27.74     0  0.609  5.983  98.8  1.8681    4
# 492         493  0.11132  0.0  27.74     0  0.609  5.983  83.5  2.1099    4
#
#      tax  ptratio  lstat  medv
# 488  711     20.1  18.06  15.2
# 489  711     20.1  23.97   7.0
# 490  711     20.1  29.68   8.1
# 491  711     20.1  18.07  13.6
# 492  711     20.1  13.35  20.1

# %%
#Find the average Pupil-teacher ratios, then graph the Pupil-teacher ratios to fnd the outliers
df.boxplot(column=["ptratio"])
# Out:
# <AxesSubplot:>

# %%
#Which tracts are outliers by which are above the 75% line
df.loc[df.ptratio > 20.2].head()
# Out:
#     Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 13          14  0.62976  0.0   8.14     0  0.538  5.949  61.8  4.7075    4
# 14          15  0.63796  0.0   8.14     0  0.538  6.096  84.5  4.4619    4
# 15          16  0.62739  0.0   8.14     0  0.538  5.834  56.5  4.4986    4
# 16          17  1.05393  0.0   8.14     0  0.538  5.935  29.3  4.4986    4
# 17          18  0.78420  0.0   8.14     0  0.538  5.990  81.7  4.2579    4
#
#     tax  ptratio  lstat  medv
# 13  307     21.0   8.26  20.4
# 14  307     21.0  10.26  18.2
# 15  307     21.0   8.47  19.9
# 16  307     21.0   6.58  23.1
# 17  307     21.0  14.67  17.5

# %% [markdown]
# (e) How many of the census tracts in this data set bound the Charles river?

# %%
len(df.loc[df['chas'] == 1])
# Out:
# 35

# %% [markdown]
# (f) What is the median pupil-teacher ratio among the towns in this data set?

# %%
df['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# (g) Which census tract of Boston has lowest median value of owner-occupied homes? What are the values of the other predictors for that census tract, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
#Lowest median value of owner-occupied homes
df[df.medv == df.medv.min()]
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 398         399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24
# 405         406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24
#
#      tax  ptratio  lstat  medv
# 398  666     20.2  30.59   5.0
# 405  666     20.2  22.98   5.0

# %%
df.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# *The crime rate was significantly higher than the average. The zn is lower than average. The industry is only moderately above average. The nox is is roughly average. The rm is about average. The dis is lower than average. The rad is significantly higher than mean. The tax is higher than average. The ptratio is lower than usual. The lstat is lower than average.
# Resultantly, it would be correlated with being a less desirable location to live.*

# %% [markdown]
# (h) In this data set, how many of the census tracts average more than seven rooms per dwelling? More than eight rooms per
# dwelling? Comment on the census tracts that average more than eight rooms per dwelling.

# %%
#more than seven rooms per dwelling
len(df.loc[df.rm > 7])
# Out:
# 64

# %%
#more than eight rooms per dwelling
len(df.loc[df.rm > 8])
# Out:
# 13

# %%
#info about those with more than 8 rooms per dwelling
df.loc[df.rm > 8].head()
# Out:
#      Unnamed: 0     crim    zn  indus  chas     nox     rm   age     dis  rad  \
# 97           98  0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2
# 163         164  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5
# 204         205  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4
# 224         225  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8
# 225         226  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8
#
#      tax  ptratio  lstat  medv
# 97   276     18.0   4.21  38.7
# 163  403     14.7   3.32  50.0
# 204  224     14.7   2.88  50.0
# 224  307     17.4   4.14  44.8
# 225  307     17.4   4.63  50.0

# %% [markdown]
# *The average tax rate is significantly higher than average, and crime rates are significantly lower.*
